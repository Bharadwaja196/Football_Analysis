# %%
# %pip install ultralytics roboflow
# Out:
# ...
#   Using cached idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# ...
# Using cached idna-3.7-py3-none-any.whl (66 kB)
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Get Dataset

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="8ISrB8KhZLkTAOkLsgcq") # THIS API KEY IS REVOKED. PLEASE USE YOUR OWN API KEY
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
dataset.location
# Out:
# 'c:\\Users\\sarma\\OneDrive\\Documents\\FinalYearProject\\Football_Analysis\\training\\football-players-detection-1'

# %%
import shutil

src_base = "football-players-detection-1/football-players-detection-1"
dst_base = "football-players-detection-1"

shutil.move(f"{src_base}/train", f"{dst_base}/train")
shutil.move(f"{src_base}/test", f"{dst_base}/test")
shutil.move(f"{src_base}/valid", f"{dst_base}/valid")
# Out:
# 'football-players-detection-1/valid'

# %% [markdown]
# # Training

# %%
# !yolo task=detect mode=train model=yolov5x.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
# Out:
# PRO TIP  Replace 'model=yolov5x.pt' with new 'model=yolov5xu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
#
# ...
# ...
# ...
# Traceback (most recent call last):
#   File "C:\Users\sarma\Miniconda3\envs\football-analytics\lib\site-packages\ultralytics\utils\downloads.py", line 347, in safe_download
#     data = response.read(buffer_size)
#   File "C:\Users\sarma\Miniconda3\envs\football-analytics\lib\http\client.py", line 463, in read
#     n = self.readinto(b)
#   File "C:\Users\sarma\Miniconda3\envs\football-analytics\lib\http\client.py", line 507, in readinto
#     n = self.fp.readinto(b)
#   File "C:\Users\sarma\Miniconda3\envs\football-analytics\lib\socket.py", line 716, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\sarma\Miniconda3\envs\football-analytics\lib\ssl.py", line 1277, in recv_into
# ...
